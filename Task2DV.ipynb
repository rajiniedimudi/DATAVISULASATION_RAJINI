# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("/content/Housing.csv")
sns.set(style="whitegrid")

# 1. Bar Chart - Furnishing Status
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='furnishingstatus', palette='pastel')
plt.title("Bar Chart: Furnishing Status")
plt.show()
S
# 2. Histogram - Price Distribution
plt.figure(figsize=(6,4))
sns.histplot(df['price'], kde=True, color='skyblue')
plt.title("Histogram: House Price Distribution")
plt.show()

# 3. Boxplot - Area
plt.figure(figsize=(6,4))
sns.boxplot(x=df['area'], color='lightgreen')
plt.title("Boxplot: House Area")
plt.show()
# Out:
# /tmp/ipython-input-3058413698.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='furnishingstatus', palette='pastel')
